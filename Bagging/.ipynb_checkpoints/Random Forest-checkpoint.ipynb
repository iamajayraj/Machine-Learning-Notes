# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification
import random

# %%
X,y = make_classification(n_features=5, n_redundant=0, n_clusters_per_class=1)

# %%
df= pd.DataFrame(X, columns=['col1','col2','col3','col4','col5'])
df['target'] = y
print(df.shape)
df.head()
# Out:
# (100, 6)
#        col1      col2      col3      col4      col5  target
# 0  1.166988  1.326146 -0.392851  0.150743 -2.750649       0
# 1 -0.234960 -0.741569 -2.969815 -0.035678 -2.979606       0
# 2 -0.732014  0.750311 -1.916012  0.855915 -1.205241       1
# 3 -0.172847  0.253446 -0.775095 -2.225541  0.311870       0
# 4 -0.709427  1.188376  0.625187 -1.051702 -2.528688       0

# %%
#row sampling function
def sample_rows(df,percent):
    return df.sample(int(percent*df.shape[0]),replace=True)

# %%
#function for feature sampling
def sample_features(df,percent):
    cols = random.sample(df.columns.tolist()[:-1],int(percent*(df.shape[1]-1)))
    new_df = df[cols]
    new_df['target'] = df['target']
    return new_df

# %%
#function for combined sampling
def combined_sampling(df,row_percent,col_percent):
    new_df = sample_rows(df,row_percent)
    return sample_features(new_df,col_percent)

# %%
df1= sample_rows(df,0.5)

# %%
df2= sample_rows(df,0.5)

# %%
df3= sample_rows(df,0.5)

# %%
print(df1.shape)
# Out:
# (50, 6)

# %%
df1
# Out:
#         col1      col2      col3      col4      col5  target
# 59 -1.742399 -0.009710 -0.827940  0.027880 -2.183484       1
# 54  0.332403  0.668596  1.465503  0.405145 -1.665461       1
# 22  0.753369  0.612629 -1.321711 -1.532778 -1.232235       0
# 99  0.088729 -0.232281 -0.346603  1.574839 -0.339050       1
# 9   0.585843  1.057419  1.882812  1.379960 -0.545364       1
# 50  0.833887  0.048099 -0.436976  1.037152 -0.914395       1
# 78  0.638253  0.571221  0.560636 -1.756430 -1.115527       0
# 17 -0.627487 -0.672042 -0.207320  1.204287 -0.666908       1
# 79  0.572294  2.727174 -0.194402  0.710606 -1.359631       1
# 20  0.327874 -1.612435 -0.923819 -2.125609 -1.648145       0
# 82  0.484753  0.466415 -0.566843 -2.529092 -0.176395       0
# 70 -0.610011 -1.127300  1.329602  0.561471 -1.501038       1
# 3  -0.172847  0.253446 -0.775095 -2.225541  0.311870       0
# 38  0.519907  0.127345  2.078261 -2.540349  1.336120       0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,:5],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,:5],df1.iloc[:,-1])
clf3.fit(df3.iloc[:,:5],df1.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree
plot_tree(clf1)
# Out:
# [Text(0.6666666666666666, 0.875, 'X[3] <= 0.401\ngini = 0.499\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.5, 0.625, 'X[0] <= -1.272\ngini = 0.071\nsamples = 27\nvalue = [26, 1]'),
#  Text(0.3333333333333333, 0.375, 'X[1] <= 0.15\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 23\nvalue = [0, 23]')]

# %%
plot_tree(clf2)
# Out:
# [Text(0.578125, 0.9375, 'X[4] <= -0.679\ngini = 0.499\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.34375, 0.8125, 'X[3] <= 0.637\ngini = 0.478\nsamples = 33\nvalue = [13, 20]'),
#  Text(0.1875, 0.6875, 'X[4] <= -2.275\ngini = 0.49\nsamples = 21\nvalue = [12, 9]'),
#  Text(0.125, 0.5625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.25, 0.5625, 'X[3] <= -1.113\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.125, 0.4375, 'X[2] <= 0.267\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.0625, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.1875, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.375, 0.4375, 'X[3] <= 0.227\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(0.3125, 0.3125, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4375, 0.3125, 'X[0] <= 0.235\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.375, 0.1875, 'X[2] <= -0.773\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.2857142857142857, 0.9642857142857143, 'X[2] <= -0.808\ngini = 0.499\nsamples = 50\nvalue = [26, 24]'),
#  Text(0.14285714285714285, 0.8928571428571429, 'X[2] <= -1.644\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.07142857142857142, 0.8214285714285714, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21428571428571427, 0.8214285714285714, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.42857142857142855, 0.8928571428571429, 'X[4] <= -2.744\ngini = 0.498\nsamples = 43\nvalue = [20, 23]'),
#  Text(0.35714285714285715, 0.8214285714285714, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5, 0.8214285714285714, 'X[4] <= -1.996\ngini = 0.5\nsamples = 40\nvalue = [20, 20]'),
#  Text(0.42857142857142855, 0.75, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.5714285714285714, 0.75, 'X[4] <= 0.024\ngini = 0.494\nsamples = 36\nvalue = [16, 20]'),
#  Text(0.5, 0.6785714285714286, 'X[4] <= -1.032\ngini = 0.5\nsamples = 33\nvalue = [16, 17]'),
# ...

# %%
print(clf1.predict(np.array([1.521398,0.560099,0.917154,0.185162,-1.935458]).reshape(1,5)))
print(clf2.predict(np.array([1.521398,0.560099,0.917154,0.185162,-1.935458]).reshape(1,5)))
print(clf3.predict(np.array([1.521398,0.560099,0.917154,0.185162,-1.935458]).reshape(1,5)))
# Out:
# [0]
# [0]
# [0]
# C:\Users\iamaj\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\iamaj\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\iamaj\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
df1= sample_features(df,0.5)
df1= sample_features(df,0.5)
df1= sample_features(df,0.5)
# Out:
# C:\Users\iamaj\AppData\Local\Temp\ipykernel_16036\406334237.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
# C:\Users\iamaj\AppData\Local\Temp\ipykernel_16036\406334237.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['target'] = df['target']
# C:\Users\iamaj\AppData\Local\Temp\ipykernel_16036\406334237.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df1
# Out:
#         col4      col1  target
# 0   0.150743  1.166988       0
# 1  -0.035678 -0.234960       0
# 2   0.855915 -0.732014       1
# 3  -2.225541 -0.172847       0
# 4  -1.051702 -0.709427       0
# ..       ...       ...     ...
# 95 -0.627717  1.524583       0
# 96  1.197032 -0.884126       1
# 97  1.114878 -0.202055       1
# 98 -0.048553  1.316864       0
# 99  1.574839  0.088729       1
#
# [100 rows x 3 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
clf1 = DecisionTreeClassifier()
clf2 = DecisionTreeClassifier()
clf3 = DecisionTreeClassifier()

# %%
clf1.fit(df1.iloc[:,:2],df1.iloc[:,-1])
clf2.fit(df2.iloc[:,:2],df2.iloc[:,-1])
clf3.fit(df3.iloc[:,:2],df3.iloc[:,-1])
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(clf1)
# Out:
# [Text(0.5555555555555556, 0.9166666666666666, 'X[0] <= 0.165\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.3333333333333333, 0.75, 'X[1] <= -1.478\ngini = 0.042\nsamples = 47\nvalue = [46, 1]'),
#  Text(0.2222222222222222, 0.5833333333333334, 'X[1] <= -1.849\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1111111111111111, 0.4166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3333333333333333, 0.4166666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4444444444444444, 0.5833333333333334, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.7777777777777778, 0.75, 'X[0] <= 0.693\ngini = 0.14\nsamples = 53\nvalue = [4, 49]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'X[1] <= 0.209\ngini = 0.408\nsamples = 14\nvalue = [4, 10]'),
#  Text(0.5555555555555556, 0.4166666666666667, 'X[1] <= -0.302\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
# ...

# %%
plot_tree(clf2)
# Out:
# [Text(0.42105263157894735, 0.9375, 'X[1] <= -0.04\ngini = 0.5\nsamples = 50\nvalue = [25, 25]'),
#  Text(0.21052631578947367, 0.8125, 'X[1] <= -1.768\ngini = 0.43\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.15789473684210525, 0.6875, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2631578947368421, 0.6875, 'X[0] <= 0.087\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.15789473684210525, 0.5625, 'X[0] <= -0.444\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.10526315789473684, 0.4375, 'X[0] <= -0.714\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.05263157894736842, 0.3125, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.15789473684210525, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.21052631578947367, 0.4375, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3684210526315789, 0.5625, 'X[1] <= -0.424\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
# ...

# %%
plot_tree(clf3)
# Out:
# [Text(0.39285714285714285, 0.9285714285714286, 'X[0] <= 0.238\ngini = 0.461\nsamples = 50\nvalue = [18, 32]'),
#  Text(0.14285714285714285, 0.7857142857142857, 'X[1] <= -0.21\ngini = 0.328\nsamples = 29\nvalue = [6, 23]'),
#  Text(0.09523809523809523, 0.6428571428571429, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.19047619047619047, 0.6428571428571429, 'X[1] <= -0.04\ngini = 0.457\nsamples = 17\nvalue = [6, 11]'),
#  Text(0.14285714285714285, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.23809523809523808, 0.5, 'X[0] <= -0.093\ngini = 0.337\nsamples = 14\nvalue = [3, 11]'),
#  Text(0.14285714285714285, 0.35714285714285715, 'X[1] <= 0.295\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.09523809523809523, 0.21428571428571427, 'X[0] <= -0.978\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.047619047619047616, 0.07142857142857142, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
# ...

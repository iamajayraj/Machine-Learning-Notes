# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# %%
df = pd.read_csv("E:\Datasets\session 24\iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df = df.drop('Id',axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
df['Species'] = encoder.fit_transform(df['Species'])

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0              5.1           3.5            1.4           0.2        0
# 1              4.9           3.0            1.4           0.2        0
# 2              4.7           3.2            1.3           0.2        0
# 3              4.6           3.1            1.5           0.2        0
# 4              5.0           3.6            1.4           0.2        0
# ..             ...           ...            ...           ...      ...
# 145            6.7           3.0            5.2           2.3        2
# 146            6.3           2.5            5.0           1.9        2
# 147            6.5           3.0            5.2           2.0        2
# 148            6.2           3.4            5.4           2.3        2
# 149            5.9           3.0            5.1           1.8        2
#
# [150 rows x 5 columns]

# %%
X = df.iloc[:,:4]
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y=df.iloc[:,4]
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 39             5.1           3.4            1.5           0.2
# 53             5.5           2.3            4.0           1.3
# 79             5.7           2.6            3.5           1.0
# 10             5.4           3.7            1.5           0.2
# 50             7.0           3.2            4.7           1.4
# ..             ...           ...            ...           ...
# 8              4.4           2.9            1.4           0.2
# 73             6.1           2.8            4.7           1.2
# 144            6.7           3.3            5.7           2.5
# 118            7.7           2.6            6.9           2.3
# 99             5.7           2.8            4.1           1.3
#
# [120 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'your_column' is the column for which you want to check the distribution
sns.kdeplot(df['SepalLengthCm'], fill=True, color='green')
plt.title('Kernel Density Estimation (KDE) Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'your_column' is the column for which you want to check the distribution
sns.kdeplot(df['PetalLengthCm'], fill=True, color='green')
plt.title('Kernel Density Estimation (KDE) Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'your_column' is the column for which you want to check the distribution
sns.kdeplot(df['SepalWidthCm'], fill=True, color='green')
plt.title('Kernel Density Estimation (KDE) Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'your_column' is the column for which you want to check the distribution
sns.kdeplot(df['PetalWidthCm'], fill=True, color='green')
plt.title('Kernel Density Estimation (KDE) Plot')
plt.xlabel('Values')
plt.ylabel('Density')
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()

# %%
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %% [markdown]
# # Imporoved Naive Bayes

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int32

# %%
X_New = X.iloc[:,:2]
X_New
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int32

# %%
X_New_train,X_New_test,y_train,y_test = train_test_split(X_New,y,test_size=0.2,random_state=5)

# %%
X_New_train
# Out:
#      SepalLengthCm  SepalWidthCm
# 39             5.1           3.4
# 53             5.5           2.3
# 79             5.7           2.6
# 10             5.4           3.7
# 50             7.0           3.2
# ..             ...           ...
# 8              4.4           2.9
# 73             6.1           2.8
# 144            6.7           3.3
# 118            7.7           2.6
# 99             5.7           2.8
#
# [120 rows x 2 columns]

# %%
nb_new = GaussianNB()

# %%
nb_new.fit(X_New_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb_new.predict(X_New_test)

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7666666666666667
